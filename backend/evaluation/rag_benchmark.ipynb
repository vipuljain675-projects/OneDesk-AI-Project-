# %% [markdown]
# # 🚀 OneDesk AI — RAG Evaluation & Accuracy Benchmark
#
# This notebook evaluates the **OneDesk AI Multi-Domain RAG Pipeline** across 4 key enterprise domains:
# - 💻 **IT Support & Hardware**
# - 👥 **HR & Leave Policies**
# - 💰 **Finance & Expenses**
# - 🏢 **Facilities & Reservations**
#
# ### Metrics Evaluated (Industry Standard RAG Triad):
# 1. **Domain Routing Accuracy:** Did the query get routed to the correct department?
# 2. **Vector Retrieval Hit Rate:** Did the semantic vector search retrieve relevant policy chunks?
# 3. **Answer Grounding Quality:** Is the generated answer grounded in campus knowledge?
# 4. **Composite System Score:** Combined benchmark accuracy.

# %%
# Run the live benchmark evaluation against the RAG pipeline
# !python evaluation/run_benchmark.py

# %% [markdown]
# ## 📊 Benchmark Summary Table & Visual Chart
# You can view the generated report in `backend/evaluation/RAG_BENCHMARK_REPORT.md`
